# %%
import cv2

# %%
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("/image.jpg")

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x400 at 0x7FD76A589D90>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # New Section

# %%
cv2.imwrite("img2.png",img)
# Out:
# True

# %%
import matplotlib.image as mlt

# %% [markdown]
# using matplotlib for showing image

# %%
img = mlt.imread("/image.jpg")

# %%
print(img)
# Out:
# [[[253  25 114]
#   [254  26 115]
#   [255  28 118]
#   ...
#   [ 72   0 135]
#   [ 70   0 132]
#   [ 67   0 129]]
#
#  [[253  25 114]
#   [254  26 115]
#   [255  28 118]
#   ...
#   [ 75   0 136]
#   [ 73   0 134]
#   [ 73   0 133]]
#
#  [[252  24 111]
#   [254  26 115]
#   [255  26 117]
#   ...
#   [ 80   0 138]
#   [ 78   0 136]
#   [ 78   2 136]]
#
#  ...
#
#  [[217   0  55]
#   [217   0  55]
#   [216   1  58]
#   ...
#   [203   0  47]
#   [202   0  48]
#   [202   0  50]]
#
#  [[215   1  55]
#   [215   1  55]
#   [215   0  57]
#   ...
#   [206   0  48]
#   [204   0  49]
#   [204   0  51]]
#
#  [[215   1  55]
#   [215   1  55]
#   [215   0  57]
#   ...
#   [207   1  49]
#   [207   1  50]
#   [205   1  52]]]

# %%
print(img[1,255,0])
#finding intensity of a particular pixel
# Out:
# 63

# %%
#to show image as imshow() doesn't work
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
img2 = mlt.imread("/mix.jpg")
img2 = cv2.imread("/mix.jpg")

# %%
plt.imshow(img2)
#it works on BGR

# %%
cv2_imshow(img2)
#cv2 works on rgb model
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7FD768792E90>

# %%
from PIL import Image

# %%
img3 = Image.open("/mix.jpg")

# %%
print(img3)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183 at 0x7FD76879BE50>

# %%
display(img3)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183 at 0x7FD76879BE50>

# %% [markdown]
# **QUESTION_Write a program to read, write and display an image using
# opencv ,matplotlib and PIL library**

# %%
#print(img.size)
#150738
print(img3.size)
# Out:
# (275, 183)

# %%
print(img.shape)#works on opencv
# Out:
# (400, 600, 3)

# %%
import skimage.io as ski

# %%
img4 = ski.imread("/mix.jpg")

# %%
ski.imshow(img4)
